# %% [markdown]
# # Netflix Data Analysis Project

# %%
#importing pandas lib
import pandas as pd

#importing nexflix dataset
netflix_data = pd.read_csv(r"/Users/yasmeensaeed/Netflix Data Analysis/Netflix_data.csv")

# %%
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country        Release_Date  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating   Duration                                               Type  \
# 0     TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     TV-MA     93 min                       Dramas, International Movies
# 2         R     78 min                Horror Movies, International Movies
# 3     PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4     PG-13    123 min                                             Dramas
# ...     ...        ...                                                ...
# 7784  TV-MA     99 min                       Dramas, International Movies
# 7785  TV-14    111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA     44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG   1 Season                 International TV Shows, Reality TV
# 7788  TV-MA     90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...
#
# [7789 rows x 11 columns]

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#Finding any duplicate records.
netflix_data[netflix_data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#Removing the duplicate records.
netflix_data.drop_duplicates(inplace= True)

# %%
netflix_data[netflix_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
#checking for amount of null values in each column.
netflix_data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#importing seaborn for heatmap use to identify nulls
import seaborn as sns

# %%
sns.heatmap(netflix_data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Content Analysis:
# ###  1 - How many new TV shows and movies were added to Netflix in 2021?
# ###  2 - What is the average duration (runtime) of movies on Netflix in 2021?
# ###  3 - Are there any notable directors, actors, or producers who were particularly active on Netflix in 2021?

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %%
#change release date Dtype to datetime
netflix_data['Release_Date'] = pd.to_datetime(netflix_data['Release_Date'], errors = 'coerce')

#Splitting Duration into Min/Season and Unit for future calculations
netflix_data[['Min/Season','Unit']] = netflix_data['Duration'].str.split(" " ,expand=True)

#Converting Min/Season into int
netflix_data["Min/Season"] = pd.to_numeric(netflix_data['Min/Season'], errors = 'coerce')
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   datetime64[ns]
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Min/Season    7787 non-null   int64
#  12  Unit          7787 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 851.7+ KB

# %%
#Checking splitting of Duration.
netflix_data.loc[0:20]
# Out:
#    Show_Id Category                 Title              Director  \
# 0       s1  TV Show                    3%                   NaN
# 1       s2    Movie                 07:19     Jorge Michel Grau
# 2       s3    Movie                 23:59          Gilbert Chan
# 3       s4    Movie                     9           Shane Acker
# 4       s5    Movie                    21        Robert Luketic
# 5       s6  TV Show                    46           Serdar Akar
# 6       s7    Movie                   122       Yasir Al Yasiri
# 7       s8    Movie                   187        Kevin Reynolds
# 8       s9    Movie                   706         Shravan Kumar
# 9      s10    Movie                  1920          Vikram Bhatt
# 10     s11    Movie                  1922          Zak Hilditch
# 11     s12  TV Show                  1983                   NaN
# 12     s13  TV Show                  1994  Diego Enrique Osorno
# 13     s14    Movie                 2,215   Nottapon Boonprakob
# 14     s15    Movie                  3022            John Suits
# 15     s16    Movie                Oct-01        Kunle Afolayan
# 16     s17  TV Show                Feb-09                   NaN
# 17     s18    Movie                22-Jul       Paul Greengrass
# 18     s19    Movie                15-Aug    Swapnaneel Jayakar
# 19     s20    Movie                   '89                   NaN
# 20     s21    Movie  ​​Kuch Bheege Alfaaz                  Onir
#
#                                                  Cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...
# 9   Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...
# 12                                                NaN
# 13                                 Artiwara Kongmalai
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# 17  Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# 19                 Lee Dixon, Ian Wright, Paul Merson
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...
#
#                            Country Release_Date Rating   Duration  \
# 0                           Brazil   2020-08-14  TV-MA  4 Seasons
# 1                           Mexico   2016-12-23  TV-MA     93 min
# 2                        Singapore   2018-12-20      R     78 min
# 3                    United States   2017-11-16  PG-13     80 min
# 4                    United States   2020-01-01  PG-13    123 min
# 5                           Turkey   2017-07-01  TV-MA   1 Season
# 6                            Egypt   2020-06-01  TV-MA     95 min
# 7                    United States   2019-11-01      R    119 min
# 8                            India   2019-04-01  TV-14    118 min
# 9                            India   2017-12-15  TV-MA    143 min
# 10                   United States   2017-10-20  TV-MA    103 min
# 11           Poland, United States   2018-11-30  TV-MA   1 Season
# 12                          Mexico   2019-05-17  TV-MA   1 Season
# 13                        Thailand   2019-03-01  TV-MA     89 min
# 14                   United States   2020-03-19      R     91 min
# 15                         Nigeria   2019-09-01  TV-14    149 min
# 16                             NaN   2019-03-20  TV-14   1 Season
# 17  Norway, Iceland, United States   2018-10-10      R    144 min
# 18                           India   2019-03-29  TV-14    124 min
# 19                  United Kingdom   2018-05-16  TV-PG     87 min
# 20                           India   2018-09-01  TV-14    110 min
#
#                                                  Type  \
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                        Dramas, International Movies
# 2                 Horror Movies, International Movies
# 3   Action & Adventure, Independent Movies, Sci-Fi...
# 4                                              Dramas
# 5     International TV Shows, TV Dramas, TV Mysteries
# 6                 Horror Movies, International Movies
# 7                                              Dramas
# 8                 Horror Movies, International Movies
# 9      Horror Movies, International Movies, Thrillers
# 10                                  Dramas, Thrillers
# 11  Crime TV Shows, International TV Shows, TV Dramas
# 12  Crime TV Shows, Docuseries, International TV S...
# 13  Documentaries, International Movies, Sports Mo...
# 14    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 15            Dramas, International Movies, Thrillers
# 16                  International TV Shows, TV Dramas
# 17                                  Dramas, Thrillers
# 18               Comedies, Dramas, Independent Movies
# 19                                      Sports Movies
# 20   Dramas, Independent Movies, International Movies
#
#                                           Description  Min/Season     Unit
# 0   In a future where the elite inhabit an island ...           4  Seasons
# 1   After a devastating earthquake hits Mexico Cit...          93      min
# 2   When an army recruit is found dead, his fellow...          78      min
# 3   In a postapocalyptic world, rag-doll robots hi...          80      min
# 4   A brilliant group of students become card-coun...         123      min
# 5   A genetics professor experiments with a treatm...           1   Season
# 6   After an awful accident, a couple admitted to ...          95      min
# 7   After one of his high school students attacks ...         119      min
# 8   When a doctor goes missing, his psychiatrist w...         118      min
# 9   An architect and his wife move into a castle t...         143      min
# 10  A farmer pens a confession admitting to his wi...         103      min
# 11  In this dark alt-history thriller, a naïve law...           1   Season
# 12  Archival video and new interviews examine Mexi...           1   Season
# 13  This intimate documentary follows rock star Ar...          89      min
# 14  Stranded when the Earth is suddenly destroyed ...          91      min
# 15  Against the backdrop of Nigeria's looming inde...         149      min
# 16  As a psychology professor faces Alzheimer's, h...           1   Season
# 17  After devastating terror attacks in Norway, a ...         144      min
# 18  On India's Independence Day, a zany mishap in ...         124      min
# 19  Mixing old footage with interviews, this is th...          87      min
# 20  After accidentally connecting over the Interne...         110      min

# %% [markdown]
# ### 1 - How many new TV shows and movies were added to Netflix in 2021?

# %%
#2021 data isolation
netflix_2021 = netflix_data[netflix_data['Release_Date'].dt.year == 2021]

# %%
#dividing into TV shows and Movies
tv_2021 = netflix_2021[netflix_2021['Category'] == 'TV Show']
movies_2021 = netflix_2021[netflix_2021['Category'] == 'Movie']

# %%
Num_tv_2021 = len(tv_2021)
Num_movies_2021 = len(movies_2021)

# %%
print(f"Number of new TV shows in 2021 is {Num_tv_2021}")
print(f"Number of new Movies in 2021 is {Num_movies_2021}")
# Out:
# Number of new TV shows in 2021 is 29
# Number of new Movies in 2021 is 88

# %% [markdown]
# ### 2 - What is the average duration (runtime) of movies on Netflix in 2021?

# %%
#using movies_2021 to collect avg duration of movies in 2021
average_movie_duration_2021 = round(movies_2021["Min/Season"].mean())
print(f"{average_movie_duration_2021} minutes")
# Out:
# 107 minutes

# %% [markdown]
# ### 3 - Are there any notable directors who were particularly active on Netflix in 2021?

# %%
#Top 5 active Movie Directors in 2021

movie_directors = movies_2021['Director'].value_counts()

top5_movie_directors = movie_directors[movie_directors > 1].nlargest(5)

#Checks if top 5 Movie directors is empty
if top5_movie_directors.empty:
     print("All Movie directors directed one Movie only hence all Equal.")
else:
    print(f"Top 5 Movie Directors \n \n{top5_movie_directors} ")

print(f"\n\n")


#Top 5 active TV Directors in 2021
tv_show_directors = tv_2021['Director'].value_counts()

top5_tv_show_directors = tv_show_directors[tv_show_directors > 1].nlargest(5)

#Checks if top 5 Tv Show directors is empty
if top5_tv_show_directors.empty:
    print("All TV show directors directed one TV show only hence all Equal.")
else:
    print(f"Top 5 TV Show Directors \n \n{top5_tv_show_directors} ")
# Out:
# Top 5 Movie Directors
#
# Martin Scorsese         2
# Michael Patrick King    2
# Prakash Jha             2
# Steven Spielberg        2
# Name: Director, dtype: int64
#
#
#
# All TV show directors directed one TV show only hence all Equal.

# %% [markdown]
# ### 4 - What is the distribution of languages in which Netflix content is available in 2021?

# %% [markdown]
# #### Using Countries Languages Dataset to link language to its country

# %%
country_languages = pd.read_excel(r"/Users/yasmeensaeed/Netflix Data Analysis/Countries_Languages.xlsx", skiprows=[0])

country_languages_subset = country_languages[['Country','Languages with official status']]

country_languages_subset.rename(columns = {'Country':'Main Country'})

country_languages_subset.head()
# Out:
#        Country Languages with official status
# 0  Afghanistan           Dari Persian, Pashto
# 1      Albania        Albanian (Tosk dialect)
# 2      Algeria                         Arabic
# 3      Andorra                        Catalan
# 4       Angola                     Portuguese

# %% [markdown]
# #### Splitting the main countries language used

# %%
movie_language_distribution = movies_2021['Country'].str.split(",",n=1, expand = True)

movie_language_distribution.columns = ['Main Country','Other Countries']
movie_language_distribution.head()
# Out:
#        Main Country        Other Countries
# 57        Indonesia                   None
# 72    United States                   None
# 104   United States                   None
# 205  United Kingdom   Spain, United States
# 366             NaN                    NaN

# %%
#dropping missing values (rows)
#missing_values = ['', 'NA', 'N/A', 'None', 'NaN', 'missing']

#movie_language_distribution_cleaned = movie_language_distribution.dropna(subset=movie_language_distribution.columns[0])
#[~movie_language_distribution.isin(missing_values).any(axis=1)]
#movie_language_distribution_cleaned.head()

# %% [markdown]
# #### Stripping trailing by cleaning spaces and making all letters are lower case to ensure clean merging

# %%
# import numpy as np
# import math

# def clean_country(country_name):
#     if isinstance(country_name, float) and math.isnan(country_name):
#         cleaned_name = "NaN"
#     else:    
#         cleaned_name = country_name.replace(" ","").lower()
#     return cleaned_name

# %%
# movie_language_distribution['Main Country'] = movie_language_distribution['Main Country'].apply(clean_country)

movie_language_distribution.head(10)
# Out:
#         Main Country        Other Countries
# 57         Indonesia                   None
# 72     United States                   None
# 104    United States                   None
# 205   United Kingdom   Spain, United States
# 366              NaN                    NaN
# 493    United States                   None
# 560            India                   None
# 601           Norway                   None
# 692    United States                   None
# 1002         Germany          United States

# %% [markdown]
# #### dropping missing values (rows)

# %%
missing_values = ['', 'NA', 'N/A', 'nan', 'NaN', 'missing']

movie_language_distribution_cleaned = movie_language_distribution[~movie_language_distribution.isin(missing_values).any(axis=1)]

# %%
merge_country_language_df = movie_language_distribution_cleaned.merge(country_languages_subset, on ='Main Country', how='left')
merge_country_language_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 merge_country_language_df = movie_language_distribution_cleaned.merge(country_languages_subset, on ='Main Country', how='left')
#       2 merge_country_language_df.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'Main Country'

# %% [markdown]
# #### Merging Country_Languages dataset to Movie_language_distribution dataset to match languages

# %%
merge_country_language_df = movie_language_distribution_cleaned.merge(country_languages_subset, on ='Country', how='left')
merge_country_language_df.rename(columns = {'Languages with official status':'Language'})
# Out:
#           Country                      Other Countries Language
# 0   unitedkingdom                 Spain, United States      NaN
# 1         germany                        United States      NaN
# 2    unitedstates                               Canada      NaN
# 3    unitedstates                               Canada      NaN
# 4          canada        United States, Cayman Islands      NaN
# 5    unitedstates                             Thailand      NaN
# 6        hongkong                        United States      NaN
# 7         germany                        United States      NaN
# 8    unitedstates                France, Canada, Spain      NaN
# 9           india                               France      NaN
# 10         france                               Canada      NaN
# 11         canada               Hungary, United States      NaN
# 12  unitedkingdom                        United States      NaN
# 13   unitedstates   Germany, United Kingdom, Australia      NaN
# 14   unitedstates                               France      NaN
# 15   unitedstates                            Hong Kong      NaN
# 16   unitedstates                       Sweden, Norway      NaN
# 17  unitedkingdom       Germany, France, United States      NaN

# %%
merge_country_language_df['Country'] = merge_country_language_df['Country'].apply(clean_country)
merge_country_language_df.rename(columns={'Languages with official status':'Language'},inplace = True)

# %%
condition = (merge_country_language_df['Country'] == 'unitedkingdom') | (merge_country_language_df['Country'] == 'unitedstates')

# Applying the condition and setting 'Language' to 'English' for the matching rows
merge_country_language_df.loc[condition, 'Language'] = 'English'

merge_country_language_df.head()
# Out:
#          Country                 Other Countries Language
# 0  unitedkingdom            Spain, United States  English
# 1        germany                   United States      NaN
# 2   unitedstates                          Canada  English
# 3   unitedstates                          Canada  English
# 4         canada   United States, Cayman Islands      NaN

# %%
language_distribution_2021 = merge_country_language_df['Language'].value_counts()

language_distribution_2021.index.name = 'Language'
language_distribution_2021.name = '# of Movies'

language_distribution_2021 = language_distribution_2021.reset_index()

print("Distribution of languages in which Netflix content is available in 2021 \n")
print(language_distribution_2021)
# Out:
# Distribution of languages in which Netflix content is available in 2021
#
#   Language  # of Movies
# 0  English           11

# %% [markdown]
# ### Visualization of Language Distribution in Bar Chart

# %%
import matplotlib.pyplot as plt

categories = language_distribution_2021['Language']
values = language_distribution_2021['# of Movies']

plt.figure(figsize=(10,6))
plt.bar(categories, values)

plt.title('Distribution of languages in Netflix Movies 2021')
plt.xlabel('Languages')
plt.ylabel('# of Movies')

plt.xticks(rotation=45)

plt.show()
